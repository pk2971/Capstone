# %%
import re

def extract_sentences_with_keywords(text, keywords):
    sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', text)
    
    filtered_sentences = [
        sentence for sentence in sentences 
        if any(re.search(rf'\b{re.escape(keyword)}\b', sentence, re.IGNORECASE) for keyword in keywords)
    ]
    
    return '\n'.join(filtered_sentences)

# %%
import os
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
from collections import Counter
from nltk.corpus import stopwords
from concurrent.futures import ThreadPoolExecutor
import nltk

nltk.download('stopwords')

keywords_to_match = ['she', 'her', 'hers', 'lady', 'ladies', 'woman', 'women', 'girl', 'girls']

stop_words = set(stopwords.words('english'))

# Specify the directory containing your files
directory = '/Users/praharshita/Desktop/Capstone/cleaned_files_by_year'

# List of words to be excluded
exclude_words = ['hon', 'lord', 'said', "'s", 'would', 'could', 'house', 'mr', 'government', 'state', 'noble',
                 'secretary', 'people', "''", 'upon', 'whether', 'made', 'many', 'make', 'ask', 'one', 'may', "mr."]
exclude_words.extend(stop_words)

# Initialize an empty DataFrame to store results
df_results = pd.DataFrame(columns=['Year', 'Top Words'])

def process_file(filename):
    # Initialize a Counter to store word counts
    word_counts = Counter()

    # Read the content of the file
    file_path = os.path.join(directory, filename)
    with open(file_path, 'r', encoding='utf-8') as file:
        print(file_path)
        content = file.read()
        pronoun_content = extract_sentences_with_keywords(content, keywords_to_match)

    # Tokenize and apply any necessary preprocessing
    # You can add more preprocessing steps based on your specific needs
    tokens = pronoun_content.lower().split()

    # Exclude specified words
    tokens = [token for token in tokens if token not in exclude_words]

    # Update word counts for the current year
    word_counts.update(tokens)

    # Get the top 5 words for the current year
    top_words_year = [word for word, count in word_counts.most_common(10)]

    return {'Year': filename[:-4], 'Top Words': top_words_year}

# Use ThreadPoolExecutor to parallelize file processing
with ThreadPoolExecutor() as executor:
    # Iterate through files in the directory
    results = list(executor.map(process_file, [filename for filename in os.listdir(directory) if filename.endswith('.txt')]))

# Append the results to the DataFrame
df_results = df_results.append(results, ignore_index=True)
df_results.to_csv('//Users/praharshita/Desktop/Capstone/results/top_words_woman_results.csv', index=False)

# Print the results
#print(df_results)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/praharshita/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1906.txt/Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1912.txt
#
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/2002.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1866.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1899.txt/Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1873.txt
#
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1872.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1898.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1867.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/2003.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1913.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1907.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1939.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1905.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1911.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/2001.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1859.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1871.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1865.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1864.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1870.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1858.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/2000.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1910.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1904.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1938.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1900.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1914.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1928.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/2004.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1901.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1917.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1903.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1888.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1863.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1877.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1876.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1862.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1889.txt/Users/praharshita/Desktop/Capstone/cleaned_files_by_year/2006.txt
#
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1902.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1916.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1959.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1971.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1965.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1839.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1805.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1811.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1804.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1810.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1838.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1964.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1970.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1958.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1999.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1966.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1972.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1812.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1806.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1807.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1813.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1973.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1967.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1998.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1988.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1963.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1977.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1817.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1803.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1976.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1962.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1989.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1974.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1960.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1948.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1814.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1828.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1815.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1949.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1961.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1975.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1993.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1987.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1978.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1950.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1944.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1818.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1824.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1830.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1831.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1825.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1819.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1945.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1951.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1979.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1986.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1992.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1984.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1990.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1947.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1953.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1833.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1827.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1826.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1832.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1952.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1946.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1991.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1985.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1013.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1981.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1995.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1942.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1956.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1836.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1822.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1823.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1837.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1957.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1943.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1994.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1980.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1996.txt/Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1982.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1955.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1941.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1969.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1821.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1835.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1809.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1808.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1834.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1820.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1968.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1940.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1954.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1983.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1997.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1933.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1927.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1884.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1890.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1847.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1853.txt/Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1852.txt
#
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1846.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1891.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1885.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1926.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1932.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1924.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1918.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1930.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1893.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1887.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1878.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1850.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1844.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1845.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1851.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1879.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1886.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1892.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1931.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1925.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1919.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1921.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1935.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1909.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1896.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1882.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1855.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1841.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1869.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1868.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1840.txt/Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1854.txt
#
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1101.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1883.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1897.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1908.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1934.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1920.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1936.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1922.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1881.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1895.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1842.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1856.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1857.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1843.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1894.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1880.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1923.txt
# /Users/praharshita/Desktop/Capstone/cleaned_files_by_year/1937.txt
# /var/folders/h9/24vbd1m931s_2j_jt_vy8cyr0000gn/T/ipykernel_1179/2392616605.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_results = df_results.append(results, ignore_index=True)

# %%
df_results = df_results.sort_values(by='Year')
df_results.to_csv('//Users/praharshita/Desktop/Capstone/results/top_words_woman_results.csv', index=False)

# %%
len(pronoun_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 len(pronoun_content)
#
# NameError: name 'pronoun_content' is not defined
